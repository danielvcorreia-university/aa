# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import cv2
import tensorflow as tf
from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Sequential
from keras import preprocessing
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.utils import to_categorical
from keras import layers, models, utils
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils.vis_utils import plot_model
from keras.losses import BinaryCrossentropy

# %%
# READING DATA

image_size = (150,150)
batch_size = 128

labels = [name for name in os.listdir("./archive/seg_train/seg_train") if os.path.isdir("./archive/seg_train/seg_train/"+name)]
print(labels)

X_train = tf.keras.preprocessing.image_dataset_from_directory(
    "./archive/seg_train/seg_train",
    subset='training',
    validation_split=0.2,
    labels='inferred',
    class_names=['buildings','forest','glacier','mountain','sea','street'],
    shuffle=True,
    seed=1,
    image_size=image_size,
    batch_size=batch_size)

X_validation = tf.keras.preprocessing.image_dataset_from_directory(
    "./archive/seg_train/seg_train",
    subset='validation',
    validation_split=0.2,
    labels='inferred',
    class_names=['buildings','forest','glacier','mountain','sea','street'],
    shuffle=True,
    seed=1,
    image_size=image_size,
    batch_size=batch_size)

X_test = tf.keras.preprocessing.image_dataset_from_directory(
    "./archive/seg_test/seg_test",
    labels='inferred',
    class_names=['buildings','forest','glacier','mountain','sea','street'],
    seed=1,
    shuffle=True,
    image_size=image_size,
    batch_size=batch_size)
# Out:
# ['sea', 'forest', 'buildings', 'street', 'glacier', 'mountain']
# Found 14034 files belonging to 6 classes.
# Using 11228 files for training.
# Found 14034 files belonging to 6 classes.
# Using 2806 files for validation.
# Found 3000 files belonging to 6 classes.

# %%
def ImageClassificationModel(input_shape, K):
    X_input = layers.Input(input_shape)
    X = tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255)(X_input)
    X = Sequential()(X_input)
    X = layers.ZeroPadding2D((3, 3))(X_input)
    X = layers.Conv2D(32,kernel_size=(5,5),strides=(2,2))(X)
    X = layers.BatchNormalization()(X)
    X = layers.Activation('relu')(X)
    X = layers.MaxPooling2D((2,2))(X)
    X = layers.Dropout(0.4)(X)
    
    X = layers.Conv2D(64,kernel_size=(3,3),strides=(1,1))(X)
    X = layers.BatchNormalization()(X)
    X = layers.Activation('relu')(X)
    X = layers.MaxPooling2D((2,2))(X)
    X = layers.Dropout(0.4)(X)
    
    X = layers.Conv2D(128,kernel_size=(3,3),strides=(1,1))(X)
    X = layers.BatchNormalization()(X)
    X = layers.Activation('relu')(X)
    X = layers.MaxPooling2D((2,2))(X)
    X = layers.Dropout(0.4)(X)
    
    X = layers.Flatten()(X)
    X = layers.Dense(K,activation='softmax')(X)
    X = models.Model(inputs=X_input,outputs=X)

    return X

model = ImageClassificationModel((150,150,3),6)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  zero_padding2d (ZeroPadding  (None, 156, 156, 3)      0
#  2D)
#
#  conv2d (Conv2D)             (None, 76, 76, 32)        2432
#
#  batch_normalization (BatchN  (None, 76, 76, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 76, 76, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 38, 38, 32)       0
#  )
#
#  dropout (Dropout)           (None, 38, 38, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 36, 36, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 36, 36, 64)       256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 36, 36, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 18, 18, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 18, 18, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 16, 16, 128)      512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 16, 16, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 8, 8, 128)         0
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 6)                 49158
#
# =================================================================
# Total params: 144,838
# Trainable params: 144,390
# Non-trainable params: 448
# _________________________________________________________________

# %%
model.compile(optimizer="adam",loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history = model.fit(X_train,epochs=30,batch_size=128,validation_batch_size=batch_size,validation_data=X_validation)
score = model.evaluate(X_train,batch_size=batch_size)
score = model.evaluate(X_test,batch_size=batch_size)
# Out:
# Epoch 1/40
# 88/88 [==============================] - 68s 762ms/step - loss: 1.5607 - accuracy: 0.5399 - val_loss: 1.4540 - val_accuracy: 0.5282
# Epoch 2/40
# 88/88 [==============================] - 70s 796ms/step - loss: 0.9088 - accuracy: 0.6745 - val_loss: 1.7236 - val_accuracy: 0.5225
# Epoch 3/40
# 88/88 [==============================] - 71s 801ms/step - loss: 0.8083 - accuracy: 0.7184 - val_loss: 0.9752 - val_accuracy: 0.6654
# Epoch 4/40
# 88/88 [==============================] - 89s 1s/step - loss: 0.7115 - accuracy: 0.7480 - val_loss: 0.8755 - val_accuracy: 0.6753
# Epoch 5/40
# 88/88 [==============================] - 89s 1s/step - loss: 0.6498 - accuracy: 0.7718 - val_loss: 1.9899 - val_accuracy: 0.5011
# Epoch 6/40
# 88/88 [==============================] - 98s 1s/step - loss: 0.6379 - accuracy: 0.7772 - val_loss: 1.1849 - val_accuracy: 0.6140
# Epoch 7/40
# 88/88 [==============================] - 92s 1s/step - loss: 0.6056 - accuracy: 0.7873 - val_loss: 1.8457 - val_accuracy: 0.5200
# Epoch 8/40
# 88/88 [==============================] - 90s 1s/step - loss: 0.5674 - accuracy: 0.7985 - val_loss: 0.5727 - val_accuracy: 0.7872
# Epoch 9/40
# 88/88 [==============================] - 98s 1s/step - loss: 0.5431 - accuracy: 0.8042 - val_loss: 1.1650 - val_accuracy: 0.6333
# Epoch 10/40
# 88/88 [==============================] - 91s 1s/step - loss: 0.5300 - accuracy: 0.8119 - val_loss: 1.1190 - val_accuracy: 0.6454
# Epoch 11/40
# 88/88 [==============================] - 90s 1s/step - loss: 0.4836 - accuracy: 0.8258 - val_loss: 0.8130 - val_accuracy: 0.7523
# Epoch 12/40
# 88/88 [==============================] - 89s 1s/step - loss: 0.5186 - accuracy: 0.8191 - val_loss: 0.7868 - val_accuracy: 0.7202
# Epoch 13/40
# 88/88 [==============================] - 92s 1s/step - loss: 0.4616 - accuracy: 0.8344 - val_loss: 0.8830 - val_accuracy: 0.7060
# Epoch 14/40
# 88/88 [==============================] - 97s 1s/step - loss: 0.4553 - accuracy: 0.8335 - val_loss: 0.7740 - val_accuracy: 0.7502
# Epoch 15/40
# 88/88 [==============================] - 83s 943ms/step - loss: 0.4194 - accuracy: 0.8491 - val_loss: 1.1240 - val_accuracy: 0.6372
# Epoch 16/40
# 88/88 [==============================] - 82s 928ms/step - loss: 0.4119 - accuracy: 0.8519 - val_loss: 1.2649 - val_accuracy: 0.6593
# Epoch 17/40
# 88/88 [==============================] - 73s 824ms/step - loss: 0.4105 - accuracy: 0.8538 - val_loss: 1.1076 - val_accuracy: 0.6597
# Epoch 18/40
# 88/88 [==============================] - 71s 807ms/step - loss: 0.4087 - accuracy: 0.8525 - val_loss: 0.6025 - val_accuracy: 0.7858
# Epoch 19/40
# 88/88 [==============================] - 71s 807ms/step - loss: 0.3858 - accuracy: 0.8608 - val_loss: 0.9009 - val_accuracy: 0.7035
# Epoch 20/40
# 88/88 [==============================] - 71s 809ms/step - loss: 0.3809 - accuracy: 0.8629 - val_loss: 0.4971 - val_accuracy: 0.8289
# Epoch 21/40
# 88/88 [==============================] - 74s 836ms/step - loss: 0.3616 - accuracy: 0.8684 - val_loss: 0.8621 - val_accuracy: 0.7306
# Epoch 22/40
# 88/88 [==============================] - 71s 809ms/step - loss: 0.3378 - accuracy: 0.8777 - val_loss: 0.8618 - val_accuracy: 0.7402
# Epoch 23/40
# 88/88 [==============================] - 71s 803ms/step - loss: 0.3537 - accuracy: 0.8727 - val_loss: 0.6637 - val_accuracy: 0.7730
# Epoch 24/40
# 88/88 [==============================] - 72s 818ms/step - loss: 0.3248 - accuracy: 0.8830 - val_loss: 0.8323 - val_accuracy: 0.7402
# Epoch 25/40
# 88/88 [==============================] - 71s 807ms/step - loss: 0.3198 - accuracy: 0.8836 - val_loss: 0.5692 - val_accuracy: 0.7922
# Epoch 26/40
# 88/88 [==============================] - 71s 803ms/step - loss: 0.3329 - accuracy: 0.8799 - val_loss: 0.5287 - val_accuracy: 0.8100
# Epoch 27/40
# 88/88 [==============================] - 71s 804ms/step - loss: 0.3213 - accuracy: 0.8822 - val_loss: 0.5899 - val_accuracy: 0.8022
# Epoch 28/40
# 88/88 [==============================] - 71s 802ms/step - loss: 0.2713 - accuracy: 0.9020 - val_loss: 0.6340 - val_accuracy: 0.7947
# Epoch 29/40
# 88/88 [==============================] - 71s 802ms/step - loss: 0.2787 - accuracy: 0.8977 - val_loss: 0.4592 - val_accuracy: 0.8528
# Epoch 30/40
# 88/88 [==============================] - 71s 804ms/step - loss: 0.2915 - accuracy: 0.8920 - val_loss: 0.4824 - val_accuracy: 0.8400
# Epoch 31/40
# 88/88 [==============================] - 71s 803ms/step - loss: 0.2650 - accuracy: 0.9032 - val_loss: 0.8834 - val_accuracy: 0.7163
# Epoch 32/40
# 88/88 [==============================] - 71s 803ms/step - loss: 0.2522 - accuracy: 0.9074 - val_loss: 0.5273 - val_accuracy: 0.8279
# Epoch 33/40
# 88/88 [==============================] - 71s 801ms/step - loss: 0.2633 - accuracy: 0.9024 - val_loss: 0.7851 - val_accuracy: 0.7512
# Epoch 34/40
# 88/88 [==============================] - 71s 803ms/step - loss: 0.2447 - accuracy: 0.9119 - val_loss: 1.0563 - val_accuracy: 0.6818
# Epoch 35/40
# 88/88 [==============================] - 71s 802ms/step - loss: 0.2417 - accuracy: 0.9101 - val_loss: 0.6223 - val_accuracy: 0.8019
# Epoch 36/40
# 88/88 [==============================] - 71s 806ms/step - loss: 0.2439 - accuracy: 0.9082 - val_loss: 0.6291 - val_accuracy: 0.8011
# Epoch 37/40
# 88/88 [==============================] - 71s 805ms/step - loss: 0.2345 - accuracy: 0.9119 - val_loss: 0.6937 - val_accuracy: 0.7922
# Epoch 38/40
# 88/88 [==============================] - 71s 804ms/step - loss: 0.2335 - accuracy: 0.9147 - val_loss: 0.8172 - val_accuracy: 0.7366
# Epoch 39/40
# 88/88 [==============================] - 77s 877ms/step - loss: 0.2295 - accuracy: 0.9173 - val_loss: 0.5130 - val_accuracy: 0.8403
# Epoch 40/40
# 88/88 [==============================] - 71s 803ms/step - loss: 0.2143 - accuracy: 0.9200 - val_loss: 0.7179 - val_accuracy: 0.7712
# 88/88 [==============================] - 18s 208ms/step - loss: 0.3496 - accuracy: 0.8681
# 24/24 [==============================] - 5s 205ms/step - loss: 0.7566 - accuracy: 0.7643

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Test'],loc='lower right')

plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Test'],loc='upper right')
